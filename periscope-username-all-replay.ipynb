# %%
import requests
import json
from collections import OrderedDict
import urllib

PERISCOPE_API_BASE_URL = 'https://api.periscope.tv/api/v2'
PERISCOPE_WEB_BASE_URL = 'https://www.periscope.tv'

def unescape(s):
    s = s.replace("&lt;", "<")
    s = s.replace("&gt;", ">")
    s = s.replace("&quot;", '"')
    # this has to be last:
    s = s.replace("&amp;", "&")
    return s

def get_web_public_user_session_tokens(username=None):

    user_url = '{web_base_url}/{username}'.format(web_base_url=PERISCOPE_WEB_BASE_URL, username=username)

    data_store = ""
    response = requests.get(user_url)
    if response.status_code == 200:
        html = response.text
        start = html.split('data-store="')
        end = start[1].split('"><div id="PageView"')
        data_store = json.loads(unescape(end[0]))
        
    if not data_store:
        return None

    public_tokens = data_store['SessionToken']['public']

    token_names = [
        'broadcastHistory', 'serviceToken', 'thumbnailPlaylist'
    ]

    out = {'user_id': data_store['UserBroadcastHistory']['userId']}
    for token_name in token_names:
        out[token_name] = public_tokens[token_name]['token']['session_id']

    return out

def request_api(endpoint, **params):
    url = _create_api_request_url(endpoint, **params)

    try:
        r = requests.get(url)
    except requests.exceptions.ConnectionError as e:
        raise e

    try:
        r.raise_for_status()
    except requests.exceptions.HTTPError as e:
        status_code = e.response.status_code
        if status_code == 404:
            return None
    return r.json()

def _create_api_request_url(endpoint, **params):
    params_ordered = OrderedDict(sorted(params.items()))

    url = '{base_url}/{endpoint}?{params}'.format(
        base_url=PERISCOPE_API_BASE_URL,
        endpoint=endpoint,
        params=urllib.parse.urlencode(params_ordered),
    )
    return url

def get_user_broadcast_history(username=None):
    endpoint = 'getUserBroadcastsPublic'
    session_tokens = get_web_public_user_session_tokens(username)
    if not session_tokens:
        return None

    params = {
        'user_id': session_tokens['user_id'],
        'session_id': session_tokens['broadcastHistory'],
        'all': 'true',
    }
    response = request_api(endpoint, **params)
    return response['broadcasts']

def get_broadcast_info(broadcast_id):
    endpoint = 'accessVideoPublic'
    result = request_api(endpoint, broadcast_id=broadcast_id)
    if not result:
        return None
    return result

# %%
username = 'CNNTurk'

broadcast_history = get_user_broadcast_history(username=username)

for broadcast_id in broadcast_history:
    bi = get_broadcast_info(broadcast_id['id'])
    if bi['type'] == "StreamTypeWeb":
        continue
    else:
        print(bi['replay_url'])
# Out:
# https://prod-ec-eu-central-1.video.periscope.tv/Transcoding/v1/hls/3PCz2L4VsZnLtyxlSByPft-T345-Q5GN8sIvAl0QXd1xC2VjSgPU15IFjT7agm2aj_Nu--GnShm84rN1yvjc1g/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16848730273392643753.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/_E8N1l8k6Llx3TLZ4lCE2WMITlkzICQVF1rmtMFdJbWQxggrLndOYe0s_-LNB-r4vNE-Xe8266a928ZPejC5tw/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16848732227439317723.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/inrVsEXItXLKABgprHdb0vV06vg4wo2oGT2v8kxLJ8NN51ejAhakvctz5azUDn3VT8k7vKn1xv9WVDkzoeX4uw/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866282108768716141.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/LT3TQJ1buaEbDb6CiMaJ_nH3uT2He--tE-fMcwMwKsfafouGRrULTPZhoBDD0CI_XthAbgGnixPIMjXLm0QC8A/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866287514178122879.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/61hyoN64zusuwpyaQrmIXUwBxK9iq6677_Sr6Re_Umr0V9-lzycAbV6Ptoon76GYuJkjFeT1Um_HSp-OClB_hA/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866348549872347601.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/j2uFY5j_LIFfxtDjLiCbJm77xm72r5hWX7cj2mZFOsSassYCw6YVvJ9ODlIpwPQFPlCaGqg8oXONmTNZSqRilw/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866357106045036037.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/Chg7eAf8apguIB4MTLEPKDP5FzHizzL5L3C753GrxlfeFhP3hratwtyQBX8kSBKzYw6xVI_RnkeWO8tLTUj5TA/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866451936791030229.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/VdzsOlaQJY3TvwA95bb-DzJtjivGHz_jHfgV8DmOlRwKH1Igp7rB2mjn52wTqg35umgKHgTh-C6ug-eJ_ZPgKQ/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866454282019503344.m3u8?type=replay
# https://prod-ec-eu-central-1.video.periscope.tv/Transcoding/v1/hls/RtiXRj9KAKYCFZETOBwYDHM0ilycpOGk19BcpHEMsIjieSCG8CplQeNT6Jd4uf0HLknSrWqfhg2qcormb8JWNA/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866522361857647382.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/A68g3ZIESWciF9zdKWifTo-AOuvGpPaqMrkWlXIFk_CF4s92K7VWUMtIHWUVha3bnj2lcHgY5wMCDTg0-hWuFw/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866530087756685151.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/CkusTjdVlfIc27D00bWD4BOqVmcTukuzGVQomk6VV7NzP7IlFS7r8n0AXnTepsJXQGjVJTbT3kp_jqRO-xh_og/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866541136514680150.m3u8?type=replay
# https://prod-ec-eu-central-1.video.periscope.tv/Transcoding/v1/hls/6B2tB2YjplqN1DE9esYN-xGCCqc8VBCxN4lTGVCFrTo5frDa8GZKcouaYHCEVCb5KeYmbLKUAmbUVRXfPsmelA/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866629474150335414.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/rDHJYiuYBOGO0QpGel4gW_tUyueZWZE1WgIbXSJbC8WxT0xWqa8ZMbVxDI-r0bSmew2t1zTcJCshyRjzXQ-Wwg/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866696020512561377.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/iVmz6sODM-vGvr9svEltUnoIFVKPWNg0ZdB5TMUiq3e9JCbN2tdyJeryzL87Nyy5d3a0addtZ-HVBNzoacfW-Q/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866709914831768324.m3u8?type=replay
# https://prod-ec-eu-central-1.video.periscope.tv/Transcoding/v1/hls/3foCwewolU_pVuuA9e9q3OapLQoaXMSuzSl8XRrFN0k-5vUI78DDmVgHwJD6uDVMJVrviaAFztp98Dxx7Jx40Q/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866722699798937060.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/NgfrZL99X73INvMCjI7T8BJyxmcYAwi4Tvvc6eFyp3ymmgxJWJhaxROmoaMg5XVMDEhMS9b9hiGn3a8Oz-iZzw/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866800770115099086.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/R-4zRGOq-CHbKXYn0_y8azn3ViJguc2RlDz53yq3dNT6bV9itwZdPAZArQVNhnB93s2xcgPzR8jw7fMqwpNyHA/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866812981776304481.m3u8?type=replay
# https://prod-fastly-eu-central-1.video.periscope.tv/Transcoding/v1/hls/BSSWD2vsjnW6s5gbPd1mdftdaXwMqzLgtTcxoO-WqUE0L1mDZ96QVU6ewHZ45KMPaqSF2jUIvMvlPkqBzir2HQ/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866878670630116674.m3u8?type=replay
# https://prod-ec-eu-central-1.video.periscope.tv/Transcoding/v1/hls/WpBlEuFCJIlfqN-3PQ33xLFvW6_5tg9Sf_Hiwh6cGZqFljIwJhkYs1ZkEDAW4C2jJnLbphbLRmBawhlQiS70iw/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16866888724791713038.m3u8?type=replay
# https://prod-ec-eu-central-1.video.periscope.tv/Transcoding/v1/hls/3sFw02DoEAxFqlbFrykALRbjWYoZFTFTtpSiFll3y5AuaxDYuJcYEwAqcXk-kQ7sGhwgbMeMcHSn8DZSPSzBIQ/non_transcode/eu-central-1/periscope-replay-direct-prod-eu-central-1-public/master_dynamic_16867051184182342578.m3u8?type=replay
